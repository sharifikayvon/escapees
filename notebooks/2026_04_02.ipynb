# %%
import numpy as np
import pandas as pd
import duckdb
from tqdm import tqdm

# %%
from escapees.coord_funcs import uvw_to_vT, radecplxuvw_to_vT, xyzuvw

# %%
import sys

print("Python:", sys.executable)
import importlib.util

spec = importlib.util.find_spec("escapees")
print(f"Escapees found: {spec}")
# Out:
# Python: /Users/sharifi/Documents/escapees/.venv/bin/python
# Escapees found: None
